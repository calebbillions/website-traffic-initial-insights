# %% [markdown]
# ## Loading the Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Importing the Dataset

# %%
df = pd.read_csv(r"C:\Users\Caleb\Downloads\1st Qtr projects\HNG\Stage 0\website_wata.csv")

# %%
df
# Out:
#       Page Views  Session Duration  Bounce Rate Traffic Source  Time on Page  \
# 0              5         11.051381     0.230652        Organic      3.890460
# 1              4          3.429316     0.391001         Social      8.478174
# 2              4          1.621052     0.397986        Organic      9.636170
# 3              5          3.629279     0.180458        Organic      2.071925
# 4              5          4.235843     0.291541           Paid      1.960654
# ...          ...               ...          ...            ...           ...
# 1995           1          2.724513     0.207187       Referral      1.324206
# 1996           3          0.392856     0.095559        Organic      3.824416
# 1997           4          9.899823     0.446622        Organic      1.288675
# 1998           3          0.393319     0.278340           Paid      5.037584
# 1999           3          0.882638     0.338026         Direct      5.186908
#
#       Previous Visits  Conversion Rate
# ...

# %% [markdown]
# ## Data Validation

# %%
df.dtypes
# Out:
# Page Views            int64
# Session Duration    float64
# Bounce Rate         float64
# Traffic Source       object
# Time on Page        float64
# Previous Visits       int64
# Conversion Rate     float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Page Views          0
# Session Duration    0
# Bounce Rate         0
# Traffic Source      0
# Time on Page        0
# Previous Visits     0
# Conversion Rate     0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Page Views        2000 non-null   int64
#  1   Session Duration  2000 non-null   float64
#  2   Bounce Rate       2000 non-null   float64
#  3   Traffic Source    2000 non-null   object
#  4   Time on Page      2000 non-null   float64
#  5   Previous Visits   2000 non-null   int64
#  6   Conversion Rate   2000 non-null   float64
# dtypes: float64(4), int64(2), object(1)
# memory usage: 109.5+ KB

# %% [markdown]
# ## Summary Statistics & Box plots

# %%
numerical_cols = df.select_dtypes(include=['int64', 'float64']).columns
df[numerical_cols].describe(include='all')
# Out:
#         Page Views  Session Duration  Bounce Rate  Time on Page  \
# count  2000.000000       2000.000000  2000.000000   2000.000000
# mean      4.950500          3.022045     0.284767      4.027439
# std       2.183903          3.104518     0.159781      2.887422
# min       0.000000          0.003613     0.007868      0.068515
# 25%       3.000000          0.815828     0.161986      1.935037
# 50%       5.000000          1.993983     0.266375      3.315316
# 75%       6.000000          4.197569     0.388551      5.414627
# max      14.000000         20.290516     0.844939     24.796182
#
#        Previous Visits  Conversion Rate
# count      2000.000000      2000.000000
# mean          1.978500         0.982065
# std           1.432852         0.065680
# min           0.000000         0.343665
# 25%           1.000000         1.000000
# 50%           2.000000         1.000000
# 75%           3.000000         1.000000
# max           9.000000         1.000000

# %%
df[['Page Views']].describe(include='all')
# Out:
#         Page Views
# count  2000.000000
# mean      4.950500
# std       2.183903
# min       0.000000
# 25%       3.000000
# 50%       5.000000
# 75%       6.000000
# max      14.000000

# %%
plt.figure(figsize=(4, 4))
sns.boxplot(data=df['Page Views'])
plt.title('Box plot for Page Views')
plt.xticks(rotation=45)
plt.show()

# %%
df[['Session Duration']].describe(include='all')
# Out:
#        Session Duration
# count       2000.000000
# mean           3.022045
# std            3.104518
# min            0.003613
# 25%            0.815828
# 50%            1.993983
# 75%            4.197569
# max           20.290516

# %%
plt.figure(figsize=(4, 4))
sns.boxplot(data=df['Session Duration'])
plt.title('Box plot for Session Duration')
plt.xticks(rotation=45)
plt.show()

# %%
df[['Bounce Rate']].describe(include='all')
# Out:
#        Bounce Rate
# count  2000.000000
# mean      0.284767
# std       0.159781
# min       0.007868
# 25%       0.161986
# 50%       0.266375
# 75%       0.388551
# max       0.844939

# %%
plt.figure(figsize=(4, 4))
sns.boxplot(data=df['Bounce Rate'])
plt.title('Box plot for Bounce Rate')
plt.xticks(rotation=45)
plt.show()

# %%
df[['Time on Page']].describe(include='all')
# Out:
#        Time on Page
# count   2000.000000
# mean       4.027439
# std        2.887422
# min        0.068515
# 25%        1.935037
# 50%        3.315316
# 75%        5.414627
# max       24.796182

# %%
plt.figure(figsize=(4, 4))
sns.boxplot(data=df['Time on Page'])
plt.title('Box plot for Time on Page')
plt.xticks(rotation=45)
plt.show()

# %%
df[['Previous Visits']].describe(include='all')
# Out:
#        Previous Visits
# count      2000.000000
# mean          1.978500
# std           1.432852
# min           0.000000
# 25%           1.000000
# 50%           2.000000
# 75%           3.000000
# max           9.000000

# %%
plt.figure(figsize=(4, 4))
sns.boxplot(data=df['Previous Visits'])
plt.title('Box plot for Previous Visits')
plt.xticks(rotation=45)
plt.show()

# %%
df[['Conversion Rate']].describe(include='all')
# Out:
#        Conversion Rate
# count      2000.000000
# mean          0.982065
# std           0.065680
# min           0.343665
# 25%           1.000000
# 50%           1.000000
# 75%           1.000000
# max           1.000000

# %%
plt.figure(figsize=(4, 4))
sns.boxplot(data=df['Conversion Rate'])
plt.title('Box plot for Conversion Rate')
plt.xticks(rotation=45)
plt.show()

# %%
categorical_cols = df.select_dtypes(include = ['object', 'category']).columns
if len(categorical_cols) > 0:
    print("\nFrequency Counts for Categorical Columns:")
    
df[categorical_cols[0]].value_counts()
# Out:
# Frequency Counts for Categorical Columns:
# Organic     786
# Paid        428
# Referral    301
# Social      269
# Direct      216
# Name: Traffic Source, dtype: int64

# %%
plt.figure(figsize=(7,5))
ax = sns.countplot(x='Traffic Source', data=df, 
                   order=df['Traffic Source'].value_counts().index)
plt.title('Distribution of Traffic Sources')
plt.xlabel('Traffic Source')
plt.ylabel('Count')
plt.xticks(rotation=45)

# Add data labels to each bar
for p in ax.patches:
    ax.annotate(f'{int(p.get_height())}', 
                (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha='center', va='center', 
                xytext=(0, 5), 
                textcoords='offset points')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Univariate Analysis

# %%
df[numerical_cols].hist(bins=30, figsize=(15, 10), edgecolor='black')
plt.suptitle('Distributions of Numerical Columns', y=1.02)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(data=df[numerical_cols])
plt.title('Box plots for Numerical Columns')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Multivariate Analysis

# %%
corr_matrix = df[numerical_cols].corr()
plt.figure(figsize=(10, 6))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix')
plt.show()
